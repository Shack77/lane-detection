# %%
import cv2
import numpy as np
import csv

def canny_edge(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    return cv2.Canny(blur, 50, 150)

def region_of_interest(image):
    height = image.shape[0]
    polygons = np.array([
        [(100, height), (image.shape[1] - 100, height), (image.shape[1] // 2, int(height * 0.6))]
    ])
    mask = np.zeros_like(image)
    cv2.fillPoly(mask, polygons, 255)
    return cv2.bitwise_and(image, mask)

def display_lines(image, lines):
    line_image = np.zeros_like(image)
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line.reshape(4)
            cv2.line(line_image, (x1, y1), (x2, y2), (0, 255, 0), 10)
    return line_image

def make_coordinates(image, line_parameters):
    slope, intercept = line_parameters
    y1 = image.shape[0]
    y2 = int(y1 * 0.6)
    x1 = int((y1 - intercept) / slope)
    x2 = int((y2 - intercept) / slope)
    return np.array([x1, y1, x2, y2])

def average_slope_intercept(image, lines):
    left, right = [], []
    for line in lines:
        x1, y1, x2, y2 = line.reshape(4)
        parameters = np.polyfit((x1, x2), (y1, y2), 1)
        slope, intercept = parameters
        if slope < 0:
            left.append(parameters)
        else:
            right.append(parameters)
    if len(left) == 0 or len(right) == 0:
        return np.array([])
    left_avg = np.average(left, axis=0)
    right_avg = np.average(right, axis=0)
    left_line = make_coordinates(image, left_avg)
    right_line = make_coordinates(image, right_avg)
    return np.array([left_line, right_line])

def calculate_steering_angle(image, lines):
    height, width = image.shape[0], image.shape[1]
    if len(lines) == 0:
        return 0
    left_line, right_line = lines
    mid = width // 2
    x_offset = ((left_line[2] + right_line[2]) // 2) - mid
    y_offset = height // 2
    angle = np.degrees(np.arctan2(y_offset, x_offset))
    return int(angle)

# ---- Main Execution ----

video_path = "test_video.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f"Error: Cannot open video file {video_path}")
    exit()

total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total frames in video: {total_frames}")

frame_count = 0

# CSV writer setup
csv_file = open('steering_output.csv', mode='w', newline='')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['Frame', 'Steering Angle (degrees)'])

# Video writer setup
fourcc = cv2.VideoWriter_fourcc(*'XVID')
ret, test_frame = cap.read()
out = cv2.VideoWriter('output_video.avi', fourcc, 20.0, (test_frame.shape[1], test_frame.shape[0]))
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)  # reset to frame 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1
    print(f"\nProcessing frame {frame_count} of {total_frames}")

    canny = canny_edge(frame)
    cropped = region_of_interest(canny)
    lines = cv2.HoughLinesP(cropped, 2, np.pi / 180, 100, np.array([]), minLineLength=40, maxLineGap=5)

    if lines is not None:
        averaged_lines = average_slope_intercept(frame, lines)
        if len(averaged_lines) > 0:
            line_image = display_lines(frame, averaged_lines)
            combo_image = cv2.addWeighted(frame, 0.8, line_image, 1, 1)
            angle = calculate_steering_angle(frame, averaged_lines)
            print(f"Predicted steering angle: {angle}°")
            csv_writer.writerow([frame_count, angle])
        else:
            combo_image = frame
            print("No clear lane lines detected.")
            csv_writer.writerow([frame_count, 'N/A'])
    else:
        combo_image = frame
        print("No lines detected.")
        csv_writer.writerow([frame_count, 'N/A'])

    # Write frame to output video
    out.write(combo_image)

    # Show result
    cv2.imshow("Lane Detection", combo_image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Final cleanup
cap.release()
out.release()
csv_file.close()
cv2.destroyAllWindows()
# Out:
# Total frames in video: 221
#
# Processing frame 1 of 221
# Predicted steering angle: 90°
#
# Processing frame 2 of 221
# Predicted steering angle: 90°
#
# Processing frame 3 of 221
# Predicted steering angle: 90°
#
# Processing frame 4 of 221
# Predicted steering angle: 90°
#
# Processing frame 5 of 221
# No clear lane lines detected.
#
# Processing frame 6 of 221
# No clear lane lines detected.
#
# Processing frame 7 of 221
# No clear lane lines detected.
#
# Processing frame 8 of 221
# No clear lane lines detected.
#
# Processing frame 9 of 221
# No clear lane lines detected.
#
# Processing frame 10 of 221
# No clear lane lines detected.
#
# Processing frame 11 of 221
# Predicted steering angle: 91°
#
# Processing frame 12 of 221
# Predicted steering angle: 90°
#
# Processing frame 13 of 221
# Predicted steering angle: 90°
#
# Processing frame 14 of 221
# Predicted steering angle: 91°
#
# Processing frame 15 of 221
# Predicted steering angle: 90°
#
# Processing frame 16 of 221
# Predicted steering angle: 90°
#
# Processing frame 17 of 221
# No clear lane lines detected.
#
# Processing frame 18 of 221
# No clear lane lines detected.
#
# Processing frame 19 of 221
# No clear lane lines detected.
#
# Processing frame 20 of 221
# No clear lane lines detected.
#
# Processing frame 21 of 221
# No clear lane lines detected.
#
# Processing frame 22 of 221
# No clear lane lines detected.
#
# Processing frame 23 of 221
# Predicted steering angle: 90°
#
# Processing frame 24 of 221
# Predicted steering angle: 89°
#
# Processing frame 25 of 221
# Predicted steering angle: 88°
#
# Processing frame 26 of 221
# Predicted steering angle: 89°
#
# Processing frame 27 of 221
# Predicted steering angle: 89°
#
# Processing frame 28 of 221
# Predicted steering angle: 89°
#
# Processing frame 29 of 221
# No clear lane lines detected.
#
# Processing frame 30 of 221
# No clear lane lines detected.
#
# Processing frame 31 of 221
# No clear lane lines detected.
#
# Processing frame 32 of 221
# No clear lane lines detected.
#
# Processing frame 33 of 221
# No clear lane lines detected.
#
# Processing frame 34 of 221
# No clear lane lines detected.
#
# Processing frame 35 of 221
# Predicted steering angle: 90°
#
# Processing frame 36 of 221
# Predicted steering angle: 90°
#
# Processing frame 37 of 221
# Predicted steering angle: 90°
#
# Processing frame 38 of 221
# Predicted steering angle: 90°
#
# Processing frame 39 of 221
# Predicted steering angle: 90°
#
# Processing frame 40 of 221
# Predicted steering angle: 89°
#
# Processing frame 41 of 221
# No clear lane lines detected.
#
# Processing frame 42 of 221
# No clear lane lines detected.
#
# Processing frame 43 of 221
# No clear lane lines detected.
#
# Processing frame 44 of 221
# No clear lane lines detected.
#
# Processing frame 45 of 221
# No clear lane lines detected.
#
# Processing frame 46 of 221
# No clear lane lines detected.
#
# Processing frame 47 of 221
# No clear lane lines detected.
#
# Processing frame 48 of 221
# Predicted steering angle: 90°
#
# Processing frame 49 of 221
# Predicted steering angle: 90°
#
# Processing frame 50 of 221
# Predicted steering angle: 91°
#
# Processing frame 51 of 221
# Predicted steering angle: 90°
#
# Processing frame 52 of 221
# Predicted steering angle: 90°
#
# Processing frame 53 of 221
# No clear lane lines detected.
#
# Processing frame 54 of 221
# No clear lane lines detected.
#
# Processing frame 55 of 221
# No clear lane lines detected.
#
# Processing frame 56 of 221
# No clear lane lines detected.
#
# Processing frame 57 of 221
# No clear lane lines detected.
#
# Processing frame 58 of 221
# No clear lane lines detected.
#
# Processing frame 59 of 221
# No clear lane lines detected.
#
# Processing frame 60 of 221
# Predicted steering angle: 90°
#
# Processing frame 61 of 221
# Predicted steering angle: 90°
#
# Processing frame 62 of 221
# Predicted steering angle: 90°
#
# Processing frame 63 of 221
# Predicted steering angle: 90°
#
# Processing frame 64 of 221
# Predicted steering angle: 90°
#
# Processing frame 65 of 221
# No clear lane lines detected.
#
# Processing frame 66 of 221
# No clear lane lines detected.
#
# Processing frame 67 of 221
# No clear lane lines detected.
#
# Processing frame 68 of 221
# No clear lane lines detected.
#
# Processing frame 69 of 221
# No clear lane lines detected.
#
# Processing frame 70 of 221
# No clear lane lines detected.
#
# Processing frame 71 of 221
# Predicted steering angle: 90°
#
# Processing frame 72 of 221
# Predicted steering angle: 89°
#
# Processing frame 73 of 221
# Predicted steering angle: 90°
#
# Processing frame 74 of 221
# Predicted steering angle: 90°
#
# Processing frame 75 of 221
# Predicted steering angle: 90°
#
# Processing frame 76 of 221
# Predicted steering angle: 90°
#
# Processing frame 77 of 221
# No clear lane lines detected.
#
# Processing frame 78 of 221
# No clear lane lines detected.
#
# Processing frame 79 of 221
# No clear lane lines detected.
#
# Processing frame 80 of 221
# No clear lane lines detected.
#
# Processing frame 81 of 221
# No clear lane lines detected.
#
# Processing frame 82 of 221
# No clear lane lines detected.
#
# Processing frame 83 of 221
# No clear lane lines detected.
#
# Processing frame 84 of 221
# Predicted steering angle: 89°
#
# Processing frame 85 of 221
# Predicted steering angle: 90°
#
# Processing frame 86 of 221
# Predicted steering angle: 91°
#
# Processing frame 87 of 221
# Predicted steering angle: 90°
#
# Processing frame 88 of 221
# Predicted steering angle: 90°
#
# Processing frame 89 of 221
# No clear lane lines detected.
#
# Processing frame 90 of 221
# No clear lane lines detected.
#
# Processing frame 91 of 221
# No clear lane lines detected.
#
# Processing frame 92 of 221
# No clear lane lines detected.
#
# Processing frame 93 of 221
# No clear lane lines detected.
#
# Processing frame 94 of 221
# No clear lane lines detected.
#
# Processing frame 95 of 221
# No clear lane lines detected.
#
# Processing frame 96 of 221
# No clear lane lines detected.
#
# Processing frame 97 of 221
# Predicted steering angle: 89°
#
# Processing frame 98 of 221
# Predicted steering angle: 90°
#
# Processing frame 99 of 221
# Predicted steering angle: 90°
#
# Processing frame 100 of 221
# Predicted steering angle: 89°
#
# Processing frame 101 of 221
# No clear lane lines detected.
#
# Processing frame 102 of 221
# No clear lane lines detected.
#
# Processing frame 103 of 221
# No clear lane lines detected.
#
# Processing frame 104 of 221
# No clear lane lines detected.
#
# Processing frame 105 of 221
# No clear lane lines detected.
#
# Processing frame 106 of 221
# No clear lane lines detected.
#
# Processing frame 107 of 221
# No clear lane lines detected.
#
# Processing frame 108 of 221
# No clear lane lines detected.
#
# Processing frame 109 of 221
# Predicted steering angle: 89°
#
# Processing frame 110 of 221
# Predicted steering angle: 88°
#
# Processing frame 111 of 221
# Predicted steering angle: 88°
#
# Processing frame 112 of 221
# Predicted steering angle: 89°
#
# Processing frame 113 of 221
# No clear lane lines detected.
#
# Processing frame 114 of 221
# No clear lane lines detected.
#
# Processing frame 115 of 221
# No clear lane lines detected.
#
# Processing frame 116 of 221
# No clear lane lines detected.
#
# Processing frame 117 of 221
# No clear lane lines detected.
#
# Processing frame 118 of 221
# No clear lane lines detected.
#
# Processing frame 119 of 221
# No clear lane lines detected.
#
# Processing frame 120 of 221
# Predicted steering angle: 90°
#
# Processing frame 121 of 221
# Predicted steering angle: 90°
#
# Processing frame 122 of 221
# Predicted steering angle: 90°
#
# Processing frame 123 of 221
# Predicted steering angle: 90°
#
# Processing frame 124 of 221
# Predicted steering angle: 89°
#
# Processing frame 125 of 221
# No clear lane lines detected.
#
# Processing frame 126 of 221
# No clear lane lines detected.
#
# Processing frame 127 of 221
# No clear lane lines detected.
#
# Processing frame 128 of 221
# No clear lane lines detected.
#
# Processing frame 129 of 221
# No clear lane lines detected.
#
# Processing frame 130 of 221
# No clear lane lines detected.
#
# Processing frame 131 of 221
# Predicted steering angle: 89°
#
# Processing frame 132 of 221
# Predicted steering angle: 89°
#
# Processing frame 133 of 221
# Predicted steering angle: 90°
#
# Processing frame 134 of 221
# Predicted steering angle: 89°
#
# Processing frame 135 of 221
# Predicted steering angle: 89°
#
# Processing frame 136 of 221
# Predicted steering angle: 88°
#
# Processing frame 137 of 221
# No clear lane lines detected.
#
# Processing frame 138 of 221
# No clear lane lines detected.
#
# Processing frame 139 of 221
# No clear lane lines detected.
#
# Processing frame 140 of 221
# No clear lane lines detected.
#
# Processing frame 141 of 221
# No clear lane lines detected.
#
# Processing frame 142 of 221
# No clear lane lines detected.
#
# Processing frame 143 of 221
# Predicted steering angle: 90°
#
# Processing frame 144 of 221
# Predicted steering angle: 90°
#
# Processing frame 145 of 221
# Predicted steering angle: 89°
#
# Processing frame 146 of 221
# Predicted steering angle: 89°
#
# Processing frame 147 of 221
# Predicted steering angle: 89°
#
# Processing frame 148 of 221
# Predicted steering angle: 88°
#
# Processing frame 149 of 221
# Predicted steering angle: 88°
#
# Processing frame 150 of 221
# No clear lane lines detected.
#
# Processing frame 151 of 221
# No clear lane lines detected.
#
# Processing frame 152 of 221
# No clear lane lines detected.
#
# Processing frame 153 of 221
# No clear lane lines detected.
#
# Processing frame 154 of 221
# No clear lane lines detected.
#
# Processing frame 155 of 221
# Predicted steering angle: 89°
#
# Processing frame 156 of 221
# Predicted steering angle: 89°
#
# Processing frame 157 of 221
# No clear lane lines detected.
#
# Processing frame 158 of 221
# No clear lane lines detected.
#
# Processing frame 159 of 221
# No clear lane lines detected.
#
# Processing frame 160 of 221
# No clear lane lines detected.
#
# Processing frame 161 of 221
# No lines detected.
#
# Processing frame 162 of 221
# No lines detected.
#
# Processing frame 163 of 221
# No lines detected.
#
# Processing frame 164 of 221
# No lines detected.
#
# Processing frame 165 of 221
# No lines detected.
#
# Processing frame 166 of 221
# No lines detected.
#
# Processing frame 167 of 221
# No lines detected.
#
# Processing frame 168 of 221
# No clear lane lines detected.
#
# Processing frame 169 of 221
# No clear lane lines detected.
#
# Processing frame 170 of 221
# No clear lane lines detected.
#
# Processing frame 171 of 221
# No clear lane lines detected.
#
# Processing frame 172 of 221
# No clear lane lines detected.
#
# Processing frame 173 of 221
# No clear lane lines detected.
#
# Processing frame 174 of 221
# No lines detected.
#
# Processing frame 175 of 221
# No lines detected.
#
# Processing frame 176 of 221
# No lines detected.
#
# Processing frame 177 of 221
# No lines detected.
#
# Processing frame 178 of 221
# No lines detected.
#
# Processing frame 179 of 221
# No lines detected.
#
# Processing frame 180 of 221
# No clear lane lines detected.
#
# Processing frame 181 of 221
# No clear lane lines detected.
#
# Processing frame 182 of 221
# No clear lane lines detected.
#
# Processing frame 183 of 221
# No clear lane lines detected.
#
# Processing frame 184 of 221
# No clear lane lines detected.
#
# Processing frame 185 of 221
# No clear lane lines detected.
#
# Processing frame 186 of 221
# No lines detected.
#
# Processing frame 187 of 221
# No lines detected.
#
# Processing frame 188 of 221
# No lines detected.
#
# Processing frame 189 of 221
# No lines detected.
#
# Processing frame 190 of 221
# No lines detected.
#
# Processing frame 191 of 221
# No lines detected.
#
# Processing frame 192 of 221
# No clear lane lines detected.
#
# Processing frame 193 of 221
# No clear lane lines detected.
#
# Processing frame 194 of 221
# No clear lane lines detected.
#
# Processing frame 195 of 221
# No clear lane lines detected.
#
# Processing frame 196 of 221
# No clear lane lines detected.
#
# Processing frame 197 of 221
# No clear lane lines detected.
#
# Processing frame 198 of 221
# No lines detected.
#
# Processing frame 199 of 221
# No lines detected.
#
# Processing frame 200 of 221
# No lines detected.
#
# Processing frame 201 of 221
# No lines detected.
#
# Processing frame 202 of 221
# No lines detected.
#
# Processing frame 203 of 221
# No lines detected.
#
# Processing frame 204 of 221
# No clear lane lines detected.
#
# Processing frame 205 of 221
# No clear lane lines detected.
#
# Processing frame 206 of 221
# No clear lane lines detected.
#
# Processing frame 207 of 221
# No clear lane lines detected.
#
# Processing frame 208 of 221
# No clear lane lines detected.
#
# Processing frame 209 of 221
# No clear lane lines detected.
#
# Processing frame 210 of 221
# No lines detected.
#
# Processing frame 211 of 221
# No lines detected.
#
# Processing frame 212 of 221
# No lines detected.
#
# Processing frame 213 of 221
# No lines detected.
#
# Processing frame 214 of 221
# No lines detected.
#
# Processing frame 215 of 221
# No lines detected.
#
# Processing frame 216 of 221
# No clear lane lines detected.
#
# Processing frame 217 of 221
# No clear lane lines detected.
#
# Processing frame 218 of 221
# No clear lane lines detected.
#
# Processing frame 219 of 221
# No clear lane lines detected.
#
# Processing frame 220 of 221
# No clear lane lines detected.
#
# Processing frame 221 of 221
# No lines detected.

# %%
import pandas as pd

df = pd.read_csv("./steering_output.csv")
print(df.head())
# Out:
#    Frame  Steering Angle (degrees)
# 0      1                      90.0
# 1      2                      90.0
# 2      3                      90.0
# 3      4                      90.0
# 4      5                       NaN
